# %% [markdown]
# # LetsGrowMore
# ## Task 1
# ### Image to Pencil Sketch using Python
# #### Aditya Aman

# %% [markdown]
# ##### Step 1: **Importing matplotlib and cv2 library**

# %%
import matplotlib.pyplot as plt
import cv2 as cv
# %matplotlib inline

# %% [markdown]
# ##### Setp 2:
# Reading the image and saving in img variable

# %%
img = cv.imread('img.jpg')

# %%
plt.imshow(img[:,:,::-1])
plt.axis(False)
plt.show()

# %% [markdown]
# ##### Step 3:
# Converting image from BGR to RGB color

# %%
img_rgb = cv.cvtColor(img, cv.COLOR_BGR2RGB)

# %% [markdown]
# ##### Step 4:
# Converting image from BGR to Grey scale

# %%
img_grey = cv.cvtColor(img, cv.COLOR_BGR2GRAY)

# %% [markdown]
# ##### Step 5:
# Inverting the Image

# %%
img_invert = cv.bitwise_not(img_grey)

# %% [markdown]
# ##### Step 6:
# Blurring the image using GaussianBlur function

# %%
img_blur = cv.GaussianBlur(img_invert, (111,111), 0)

# %% [markdown]
# ##### Step 7:
# Inverting the blurred image

# %%
img_blur_invert = cv.bitwise_not(img_blur)

# %% [markdown]
# ##### Step 8:
# Converting the blurred inverted image to sketch by doing bitwise division

# %%
img_sketch = cv.divide(img_grey, img_blur_invert, scale = 256.0)

# %% [markdown]
# ##### Step 9:
# Plotting the Images

# %%
plt.figure(figsize = (16,10))
plt.subplot(1,2,1)
plt.title('Original Image', size = 18)
plt.imshow(img_rgb)
plt.axis('off')

plt.subplot(1,2,2)
plt.title('Pencil Sketch', size = 18)
sketch_rgb = cv.cvtColor(img_sketch, cv.COLOR_BGR2RGB)
plt.imshow(sketch_rgb)
plt.axis('off')

plt.show()
